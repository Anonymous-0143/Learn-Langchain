# %% [markdown]
# Langchain Version V1

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent

agent=create_agent(
    model="gpt-3.5-turbo",
    tools=[],
    system_prompt="You are a helpul assistant."
)
agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from langchain.agents import create_agent
#       2
#       3 agent=create_agent(
#       4     model="gpt-3.5-turbo",
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (d:\CODING\LearnLangchain\.venv\Lib\site-packages\langchain\agents\__init__.py)

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.1.0
